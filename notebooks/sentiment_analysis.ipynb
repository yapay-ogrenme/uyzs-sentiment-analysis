# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('drive/MyDrive/twitter_sentiment')

# %% [markdown]
# ## Install Packages

# %%
# !pip install transformers

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
from tqdm.notebook import tqdm
tqdm.pandas()

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('data/Yapay_Zeka_Stratejisi_2021_08_20_2021_08_25_df.csv',encoding = 'utf-8', engine = 'python')
df
# Out:
#      Unnamed: 0  ...                                              tweet
# 0             0  ...  Türkiye'nin Yapay Zeka Stratejisi... Ulusal Ya...
# 1             1  ...  Açıklanan Türkiye Yapay Zeka Stratejisi ile il...
# 2             2  ...  @ZB6868 @firstjedii @varank Bence biraz absürd...
# 3             3  ...  Türkiye’nin İlk Ulusal Yapay Zeka Stratejisi a...
# 4             4  ...  Türkiye'nin İlk Ulusal Yapay Zeka Stratejisi a...
# ..          ...  ...                                                ...
# 657         657  ...  Bugünkü resmi gazete ile  “Ulusal Yapay Zeka S...
# 658         658  ...  Bugünkü Resmi Gazete'de (20.08.2021 T-31574 sa...
# 659         659  ...  Ulusal Yapay Zekâ Stratejisi (2021-2025) ile İ...
# 660         660  ...  Yapay zeka alanında çalışan arkadaşlar için ön...
# 661         661  ...  Ulusal Yapay Zekâ Stratejisi (2021-2025) ile İ...
#
# [662 rows x 6 columns]

# %% [markdown]
# ## Load Transformers Model

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline
# load model, it takes time since it loads over 500 MB model file
model = AutoModelForSequenceClassification.from_pretrained("savasy/bert-base-turkish-sentiment-cased")
tokenizer = AutoTokenizer.from_pretrained("savasy/bert-base-turkish-sentiment-cased")
# create pipeline
sa = pipeline("sentiment-analysis", tokenizer=tokenizer, model=model)
# Out:
# Downloading:   0%|          | 0.00/596 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/443M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/263k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %% [markdown]
# ## PreProcess

# %%
import re
import sys
from nltk.stem.porter import PorterStemmer


def preprocess_word(word):
    # Remove punctuation
    #word = word.strip('\'"?!,.():;')
    
    # Convert more than 2 letter repetitions to 2 letter
    # funnnnny --> funny
    word = re.sub(r'(.)\1+', r'\1\1', word)
    # Remove - & '
    word = re.sub(r'(-|\')', '', word)
    return word


def is_valid_word(word):
    # Check if word begins with an alphabet
    return (re.search(r'^[a-zA-Z][a-z0-9A-Z\._]*$', word) is not None)


def handle_emojis(tweet):
    # Smile -- :), : ), :-), (:, ( :, (-:, :')
    tweet = re.sub(r'(:\s?\)|:-\)|\(\s?:|\(-:|:\'\))', ' EMO_POS ', tweet)
    # Laugh -- :D, : D, :-D, xD, x-D, XD, X-D
    tweet = re.sub(r'(:\s?D|:-D|x-?D|X-?D)', ' EMO_POS ', tweet)
    # Love -- <3, :*
    tweet = re.sub(r'(<3|:\*)', ' EMO_POS ', tweet)
    # Wink -- ;-), ;), ;-D, ;D, (;,  (-;
    tweet = re.sub(r'(;-?\)|;-?D|\(-?;)|😉', ' EMO_POS ', tweet)
    # Sad -- :-(, : (, :(, ):, )-:
    tweet = re.sub(r'(:\s?\(|:-\(|\)\s?:|\)-:)', ' EMO_NEG ', tweet)
    # Cry -- :,(, :'(, :"(
    tweet = re.sub(r'(:,\(|:\'\(|:"\()', ' EMO_NEG ', tweet)
    return tweet


def preprocess_tweet(tweet):
    processed_tweet = []
    # Convert to lower case
    tweet = tweet.lower()
    
    tweet = re.sub("^\d+\s|\s\d+\s|\s\d+$", " ", tweet)
    
    # Replaces URLs with the word URL
    #tweet = re.sub(r'((www\.[\S]+)|(https?://[\S]+))', ' URL ', tweet)
    tweet = re.sub(r'((www\.[\S]+)|(https?://[\S]+))', '', tweet)
    
    # Replace @handle with the word USER_MENTION
    #tweet = re.sub(r'@[\S]+', 'USER_MENTION', tweet)
    tweet = re.sub(r'@[\S]+', '', tweet)
    
    # Replaces #hashtag with hashtag
    #tweet = re.sub(r'#(\S+)', r' \1 ', tweet)
    tweet = re.sub(r'#(\S+)', '', tweet)
    
    # Remove RT (retweet)
    tweet = re.sub(r'\brt\b', '', tweet)
    
    # Replace 2+ dots with space
    tweet = re.sub(r'\.{2,}', ' ', tweet)
    
    # Strip space, " and ' from tweet
    tweet = tweet.strip(' "\'')

    # Replace emojis with either EMO_POS or EMO_NEG
    #tweet = handle_emojis(tweet)
    
    # Replace multiple spaces with a single space
    tweet = re.sub(r'\s+', ' ', tweet)
    words = tweet.split()

    for word in words:
      word = preprocess_word(word)
      #if is_valid_word(word):
      #    processed_tweet.append(word)
      processed_tweet.append(word)

    return ' '.join(processed_tweet)

# %% [markdown]
# #Sentiment Analysis

# %%
THRESHOLD = 0.95

def get_sentiment_analysis(tweet):
    """True if tweet has positive compound sentiment, False otherwise."""
    p = sa(str(tweet))
    #print("label", p[0]["label"])
    #print("score", round(p[0]["score"],4))

    return pd.Series([p[0]["label"], round(p[0]["score"],4)])

# %%
df["sentiment_label"] = "-"
df["sentiment_score"] = -1
df[["sentiment_label", "sentiment_score"]] = df["tweet"].progress_apply(get_sentiment_analysis)

df['sentiment_score'].apply(lambda x: float(x))
# Out:
#   0%|          | 0/662 [00:00<?, ?it/s]
# 0      0.6704
# 1      0.9017
# 2      0.9990
# 3      0.5813
# 4      0.6870
#         ...
# 657    0.7368
# 658    0.8500
# 659    0.7597
# 660    0.9103
# 661    0.8053
# Name: sentiment_score, Length: 662, dtype: float64

# %%
df
# Out:
#      Unnamed: 0                   id  ... sentiment_label sentiment_score
# 0             0  1430303911487762438  ...        negative          0.6704
# 1             1  1430296179934470146  ...        positive          0.9017
# 2             2  1430291373366857736  ...        positive          0.9990
# 3             3  1430289767976116229  ...        positive          0.5813
# 4             4  1430279189106675716  ...        negative          0.6870
# ..          ...                  ...  ...             ...             ...
# 657         657  1428589924807217157  ...        negative          0.7368
# 658         658  1428583261966684161  ...        negative          0.8500
# 659         659  1428574478536151042  ...        negative          0.7597
# 660         660  1428569701056122883  ...        positive          0.9103
# 661         661  1428547221079789568  ...        negative          0.8053
#
# [662 rows x 8 columns]

# %%
df.to_csv("data/Yapay_Zeka_Stratejisi_2021_08_20_2021_08_25_df_sentiment_analysis_all.csv")

# %% [markdown]
# ## Filter Only Positive Tweets Above Threshold

# %%
df_positive_t = df[(df["sentiment_label"]=="positive") & (df["sentiment_score"]>THRESHOLD)]
df_positive_t
# Out:
#      Unnamed: 0                   id  ... sentiment_label sentiment_score
# 2             2  1430291373366857736  ...        positive          0.9990
# 11           11  1430266493892276225  ...        positive          0.9763
# 16           16  1430249798922346500  ...        positive          0.9746
# 20           20  1430246235554951171  ...        positive          0.9616
# 26           26  1430234962431729669  ...        positive          0.9614
# ..          ...                  ...  ...             ...             ...
# 581         581  1428626061311594500  ...        positive          0.9887
# 586         586  1428622499676397577  ...        positive          0.9581
# 595         595  1428617623156273158  ...        positive          0.9728
# 614         614  1428609046337228800  ...        positive          0.9842
# 631         631  1428604197151420418  ...        positive          0.9820
#
# [74 rows x 8 columns]

# %%
df_positive_t.to_csv("data/Yapay_Zeka_Stratejisi_2021_08_20_2021_08_25_df_sentiment_analysis_positive.csv")

# %% [markdown]
# ## Filter Only Negative Tweets Above Threshold

# %%
df_negative_t = df[(df["sentiment_label"]=="negative") & (df["sentiment_score"]>THRESHOLD)]
df_negative_t
# Out:
#      Unnamed: 0                   id  ... sentiment_label sentiment_score
# 5             5  1430277484822421504  ...        negative          0.9978
# 14           14  1430255053424693256  ...        negative          0.9994
# 35           35  1430212749519429635  ...        negative          0.9987
# 59           59  1430173539391451138  ...        negative          0.9912
# 105         105  1430127840532570115  ...        negative          0.9887
# 219         219  1430086544736538663  ...        negative          0.9867
# 221         221  1430085795017330688  ...        negative          0.9813
# 223         223  1430084739973664779  ...        negative          0.9688
# 250         250  1430077077462659072  ...        negative          0.9989
# 255         255  1430075226814128136  ...        negative          0.9905
# 271         271  1430071264056651777  ...        negative          0.9967
# 285         285  1430067921292775442  ...        negative          0.9757
# 299         299  1430060737733570595  ...        negative          0.9533
# 310         310  1429774654995042306  ...        negative          0.9752
# 418         418  1429118405001502728  ...        negative          0.9986
# 472         472  1428739223880863755  ...        negative          0.9878
# 477         477  1428733382675021831  ...        negative          0.9982
# 479         479  1428722555851055105  ...        negative          0.9750
# 480         480  1428722405518843908  ...        negative          0.9929
# 507         507  1428670199176339466  ...        negative          0.9986
# 555         555  1428634161380839424  ...        negative          0.9905
# 582         582  1428625307540525059  ...        negative          0.9990
# 634         634  1428603636859510786  ...        negative          0.9652
# 656         656  1428591314321481729  ...        negative          0.9897
#
# [24 rows x 8 columns]

# %%
df_negative_t.to_csv("data/Yapay_Zeka_Stratejisi_2021_08_20_2021_08_25_df_sentiment_analysis_negative.csv")
